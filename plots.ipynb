# %%
import matplotlib.pyplot as plt

# %%
import matplotlib.pyplot as plt

#Vision transformer
y1 = [0.58, 0.63, 0.65, 0.69, 0.70, 0.72, 0.75, 0.77, 0.79, 0.80, 0.83, 0.84, 0.87, 0.88, 0.90, 0.90, 0.91, 0.93, 0.93, 0.94]
#Resnet50
y2 = [0.59, 0.66, 0.70, 0.72, 0.74, 0.77, 0.79, 0.80, 0.82, 0.84, 0.85, 0.88, 0.89, 0.89, 0.90, 0.91, 0.92, 0.92, 0.93, 0.93]
#Inception V3
y3 = [0.58, 0.64, 0.68, 0.71, 0.73, 0.76, 0.80, 0.81, 0.83, 0.85, 0.86, 0.88, 0.88, 0.89, 0.91, 0.91, 0.91, 0.92, 0.92, 0.92]
#GoogLeNet
y4 = [0.58, 0.63, 0.66, 0.69, 0.70, 0.72, 0.73, 0.74, 0.76, 0.77, 0.78, 0.80, 0.82, 0.81, 0.83, 0.83, 0.85, 0.85, 0.86, 0.85]
#DenseNet
y5 = [0.58, 0.64, 0.66, 0.68, 0.70, 0.72, 0.74, 0.76, 0.77, 0.79, 0.80, 0.81, 0.82, 0.84, 0.85, 0.85, 0.87, 0.87, 0.89, 0.89]
#ResNeXt50
y6 = [0.59, 0.66, 0.70, 0.73, 0.77, 0.80, 0.83, 0.85, 0.86, 0.87, 0.89, 0.90, 0.90, 0.92, 0.92, 0.92, 0.93, 0.94, 0.94, 0.94]
#ELA+ResNeXt50
y7 = [0.69, 0.76, 0.77, 0.80, 0.83, 0.84, 0.86, 0.88, 0.91, 0.92, 0.93, 0.93, 0.95, 0.96, 0.96, 0.96, 0.97, 0.97, 0.97, 0.98]
x = range(20)
  
plt.plot(x, y1, label = "ViT")
plt.plot(x, y2, label = "ResNet")
plt.plot(x, y3, label = "Inception")
plt.plot(x, y4, label = "GoogLeNet")
plt.plot(x, y5, label = "DenseNet")
plt.plot(x, y6, label = "ResNeXt50")
plt.plot(x, y7, label = "ELA+ResNeXt50")
plt.xlabel("Epochs")
plt.ylabel("Training Accuracy")
plt.legend()
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np
from sklearn.datasets import make_classification
from sklearn.metrics import confusion_matrix, ConfusionMatrixDisplay
from sklearn.model_selection import train_test_split
from sklearn.svm import SVC

cm = np.array([[932,  68], [61, 939]])
disp = ConfusionMatrixDisplay(confusion_matrix=cm, display_labels = ["Original", "Photoshop"])
disp.plot(cmap = "Blues")
plt.show()
